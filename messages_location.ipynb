# %%
import plotly.express as px, pandas as pd
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
#Filter date range
start_date = '2014-06-08 10:00:00'
end_date = '2014-06-08 13:00:00'

comm_sun_df = pd.read_csv('hw02-data/Communication Data/comm-data-Sun.csv')
comm_sun_df['Timestamp'] = pd.to_datetime(comm_sun_df['Timestamp'])

# %%
#Amount of messages per minute on Sunday btw 11:30-12:30 for #For 'Entry Corridor'
mask_EC = (comm_sun_df['location'] == 'Entry Corridor')
comm_EC_df = comm_sun_df.loc[mask_EC]
comm_EC_df.head()

#filter by time 
comm_EC_df['min'] = comm_EC_df['Timestamp'].dt.round('min')

#Filter date range
mask = (comm_EC_df['Timestamp'] >= start_date) & (comm_EC_df['Timestamp'] <= end_date)
comm_EC_noon_df = comm_EC_df.loc[mask]

#Group by minute
comm_EC_noon_df = comm_EC_noon_df.groupby('min').size().reset_index(name='Messages')

comm_EC_noon_df.head()
# Out:
# /var/folders/5j/n7l5yr9517vb7ym9lnb_cj700000gn/T/ipykernel_58575/3598718575.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   comm_EC_df['min'] = comm_EC_df['Timestamp'].dt.round('min')
#                   min  Messages
# 0 2014-06-08 10:00:00        78
# 1 2014-06-08 10:01:00       134
# 2 2014-06-08 10:02:00        81
# 3 2014-06-08 10:03:00        61
# 4 2014-06-08 10:04:00       131

# %%
#Amount of messages per minute on Sunday btw 11:30-12:30 for #For 'Tundra Land'
mask_TL = (comm_sun_df['location'] == 'Tundra Land')
comm_TL_df = comm_sun_df.loc[mask_TL]
comm_TL_df.head()

#filter by time 
comm_TL_df['min'] = comm_TL_df['Timestamp'].dt.round('min')

#Filter date range
mask = (comm_TL_df['Timestamp'] >= start_date) & (comm_TL_df['Timestamp'] <= end_date)
comm_TL_noon_df = comm_TL_df.loc[mask]

#Group by minute
comm_TL_noon_df = comm_TL_noon_df.groupby('min').size().reset_index(name='Messages')

comm_TL_noon_df.head()
# Out:
# /var/folders/5j/n7l5yr9517vb7ym9lnb_cj700000gn/T/ipykernel_58575/2312033523.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   comm_TL_df['min'] = comm_TL_df['Timestamp'].dt.round('min')
#                   min  Messages
# 0 2014-06-08 10:00:00        43
# 1 2014-06-08 10:01:00       205
# 2 2014-06-08 10:02:00       192
# 3 2014-06-08 10:03:00       514
# 4 2014-06-08 10:04:00       260

# %%
#Amount of messages per minute on Sunday btw 11:30-12:30 for #For 'Kiddie Land'
mask_KL = (comm_sun_df['location'] == 'Kiddie Land')
comm_KL_df = comm_sun_df.loc[mask_KL]
comm_KL_df.head()

#filter by time group by minute
comm_KL_df['min'] = comm_KL_df['Timestamp'].dt.round('min')

#
mask = (comm_KL_df['Timestamp'] >= start_date) & (comm_KL_df['Timestamp'] <= end_date)
comm_KL_noon_df = comm_KL_df.loc[mask]

#Group by minute
comm_KL_noon_df = comm_KL_noon_df.groupby('min').size().reset_index(name='Messages')

comm_KL_noon_df.head()
# Out:
# /var/folders/5j/n7l5yr9517vb7ym9lnb_cj700000gn/T/ipykernel_58575/3253049630.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   comm_KL_df['min'] = comm_KL_df['Timestamp'].dt.round('min')
#                   min  Messages
# 0 2014-06-08 10:00:00       187
# 1 2014-06-08 10:01:00       105
# 2 2014-06-08 10:02:00       149
# 3 2014-06-08 10:03:00        87
# 4 2014-06-08 10:04:00       172

# %%
#Amount of messages per minute on Sunday btw 11:30-12:30 for #For 'Wet Land'
mask_WL = (comm_sun_df['location'] == 'Wet Land')
comm_WL_df = comm_sun_df.loc[mask_WL]
comm_WL_df.head()

#filter by time 
comm_WL_df['min'] = comm_WL_df['Timestamp'].dt.round('min')
mask = (comm_WL_df['Timestamp'] >= start_date) & (comm_WL_df['Timestamp'] <= end_date)
comm_WL_noon_df = comm_WL_df.loc[mask]

#Group by minute
comm_WL_noon_df = comm_WL_noon_df.groupby('min').size().reset_index(name='Messages')

comm_WL_noon_df.head()
# Out:
# /var/folders/5j/n7l5yr9517vb7ym9lnb_cj700000gn/T/ipykernel_58575/287999346.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   comm_WL_df['min'] = comm_WL_df['Timestamp'].dt.round('min')
#                   min  Messages
# 0 2014-06-08 10:00:00       459
# 1 2014-06-08 10:01:00       659
# 2 2014-06-08 10:02:00       703
# 3 2014-06-08 10:03:00       858
# 4 2014-06-08 10:04:00       650

# %%
#Amount of messages per minute on Sunday btw 11:30-12:30 for #For 'Coaster Alley'
mask_CA = (comm_sun_df['location'] == 'Coaster Alley')
comm_CA_df = comm_sun_df.loc[mask_CA]
comm_CA_df.head()

#filter by time group by minute
comm_CA_df['min'] = comm_CA_df['Timestamp'].dt.round('min')
mask = (comm_CA_df['Timestamp'] >= start_date) & (comm_CA_df['Timestamp'] <= end_date)
comm_CA_noon_df = comm_CA_df.loc[mask]

#Group by minute
comm_CA_noon_df = comm_CA_noon_df.groupby('min').size().reset_index(name='Messages')

comm_CA_noon_df.head()
# Out:
# /var/folders/5j/n7l5yr9517vb7ym9lnb_cj700000gn/T/ipykernel_58575/2824037461.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   comm_CA_df['min'] = comm_CA_df['Timestamp'].dt.round('min')
#                   min  Messages
# 0 2014-06-08 10:00:00        90
# 1 2014-06-08 10:01:00       124
# 2 2014-06-08 10:02:00       184
# 3 2014-06-08 10:03:00       224
# 4 2014-06-08 10:04:00       212

# %%
fig = make_subplots(rows=5, cols=1, subplot_titles=["Entry Corridor", "Tundra Land", "Kiddie Land", "Wet Land", "Coaster Alley"])

# EC plot (First row)
fig.add_trace(
    go.Scatter(x=comm_EC_noon_df['min'], 
               y=comm_EC_noon_df['Messages'], 
               mode='lines', name='Entry Corridor',
               fill='tozeroy',
               line=dict(color="gray")),
    row=1, col=1
)

# TL plot (Second row)
fig.add_trace(
    go.Scatter(x=comm_TL_noon_df['min'], 
               y=comm_TL_noon_df['Messages'], 
               mode='lines', name='Tundra Land',
               fill ='tozeroy',
               line=dict(color="#5588FF")),
    row=2, col=1
)

# KL plot (Third row)
fig.add_trace(
    go.Scatter(x=comm_KL_noon_df['min'], 
               y=comm_KL_noon_df['Messages'], 
               mode='lines', name='Kiddie Land', 
               fill='tozeroy',
               line=dict(color="#FDBB33")),
    row=3, col=1
)

# WL plot (Fourth row)
fig.add_trace(
    go.Scatter(x=comm_WL_noon_df['min'], 
               y=comm_WL_noon_df['Messages'], 
               mode='lines', name='Wet Land', 
               fill='tozeroy',
               line=dict(color="#11CC55")),
    row=4, col=1
)

# CA plot (Fifth row)
fig.add_trace(
    go.Scatter(x=comm_CA_noon_df['min'], 
               y=comm_CA_noon_df['Messages'], 
               mode='lines', name='Coaster Alley', 
               fill='tozeroy',
               line=dict(color="red")),
    row=5, col=1
)

fig.update_layout(
    height=1000, width=800, 
    title_text="Frequency of Messages Per Ten Minutes (Friday to Sunday)", 

    # Set y-axis ranges for each subplot
    yaxis=dict(range=[0, 3000], title='Number of Messages'),
    yaxis2=dict(range=[0, 3000], title='Number of Messages'),
    yaxis3=dict(range=[0, 3000], title='Number of Messages'),
    yaxis4=dict(range=[0, 3000], title='Number of Messages'),
    yaxis5=dict(range=[0, 3000], title='Number of Messages'),


    xaxis=dict(title='Time'),
    xaxis2=dict(title='Time'),
    xaxis3=dict(title='Time'),
    xaxis4=dict(title='Time'),
    xaxis5=dict(title='Time')

)

# Display the figure
fig.show()
